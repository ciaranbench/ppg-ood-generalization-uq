# %%
import numpy as np
import pickle
import torch

# %%
a =np.load('test_latents.pkl',allow_pickle=True)

# %%
len(a[0])
# Out:
# 177

# %%
np.shape(a[0][0])
# Out:
# (1, 64, 512)

# %%
b =np.load('test_epi_dbp.pkl',allow_pickle=True)

# %%
np.shape(b[0][0])
# Out:
# torch.Size([64])
